# %% [markdown]
# The aim of this book is to get the longitude and latitude of each building on campus.

# %%
import pandas as pd
import os
import sqlite3 as sql
import re
import requests
from bs4 import BeautifulSoup
import json
from time import sleep
import random
import requests_cache
import geopandas as gpd         
import osmnx as ox            
import shapely.geometry as geom
from shapely.geometry import Point, Polygon

requests_cache.install_cache('googlimap')

# %%
dire = os.getcwd()
dire = os.path.dirname(dire)
db = sql.connect(dire+"/data.db")

# %%
cursor = db.execute("SELECT * FROM sqlite_master")

# %%
loca = pd.read_sql("SELECT DISTINCT(location) FROM coursedtl",db)

# %%
loca["location"] = loca["location"].str.replace(r'TBA', r'')

loca = loca.drop_duplicates()

loca = loca.reset_index(drop=True)

loca = loca.loc[loca.location != '  ',]

# %%
loca.head()
# Out:
#             location
# 0   Wellman Hall 230
# 1   Wellman Hall 212
# 2   Wellman Hall 202
# 3   Wellman Hall 234
# 4    Wellman Hall 27

# %%
loca["northeast"] = 0
loca["southwest"] = 0
loca["represent"] = 0

# %%
t = dict({"lat":"etq","lon":"3qt"})

# %%
for index,row in loca.iterrows():
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    bld = row.location
    print(bld)
    sleep(random.randrange(1,3))
    param = {"address":bld+",Davis,CA",
            "key":"AIzaSyC253_KkSFPSTGKoJpNoTRX4zNtnGk7HMI"}
    res = requests.get(url,params = param)
    t = json.loads(res.text)
    try:
        northeast = t["results"][0]["geometry"]["viewport"]["northeast"]
        southwest = t["results"][0]["geometry"]["viewport"]["southwest"]
        represent =  t["results"][0]["geometry"]["location"]
        print(northeast.values())
    except IndexError:
        northeast = {}
        southwest = {}
        represent = {}
    loca.loc[index,'northeast']= str(list(northeast.values()))
    loca.loc[index,'southwest']= str(list(southwest.values()))
    print(southwest)
    loca.loc[index,'represent']= str(list(represent.values()))
# Out:
#  Wellman Hall 230
# dict_values([38.5426904802915, -121.7500650197085])
# {'lat': 38.5399925197085, 'lng': -121.7527629802915}
#  Wellman Hall 212
# dict_values([38.5433700802915, -121.7531927197085])
# {'lat': 38.5406721197085, 'lng': -121.7558906802915}
#  Wellman Hall 202
# dict_values([38.5426904802915, -121.7500650197085])
# {'lat': 38.5399925197085, 'lng': -121.7527629802915}
#  Wellman Hall 234
# dict_values([38.5426904802915, -121.7500650197085])
# {'lat': 38.5399925197085, 'lng': -121.7527629802915}
#  Wellman Hall 27
# dict_values([38.5426904802915, -121.7500650197085])
# {'lat': 38.5399925197085, 'lng': -121.7527629802915}
#  Hunt 110
# dict_values([38.5439328802915, -121.7381902197085])
# {'lat': 38.5412349197085, 'lng': -121.7408881802915}
#  Wellman Hall 209
# dict_values([38.5426904802915, -121.7500650197085])
# {'lat': 38.5399925197085, 'lng': -121.7527629802915}
#  Wellman Hall 105
# dict_values([38.54268743029149, -121.7500608197085])
# ...

# %%
loca.to_csv("loca.csv")
